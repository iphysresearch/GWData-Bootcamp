# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = sns.load_dataset("flights")
data.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
number_year = data.groupby("year")[['passengers']].sum()
number_year.head()
# Out:
#       passengers
# year
# 1949        1520
# 1950        1676
# 1951        2042
# 1952        2364
# 1953        2700

# %%
fig = plt.figure(figsize = (14,7))
x = number_year.index
y = number_year['passengers']
plt.plot(x,y,'b',label = 'passenger number')
plt.title('The number of passengers in each year')
plt.xlabel('year')
plt.ylabel('number')
# Out:
# Text(0, 0.5, 'number')

# %%
month_year = data.groupby("month")[['passengers']].sum()
month_year
# Out:
#        passengers
# month
# Jan          2901
# Feb          2820
# Mar          3242
# Apr          3205
# May          3262
# Jun          3740
# Jul          4216
# Aug          4213
# Sep          3629
# Oct          3199
# Nov          2794
# Dec          3142

# %%
month_year.index = np.arange(1,13)

fig = plt.figure(figsize=(10,5))
x1 = month_year.index
y1 = month_year["passengers"]
plt.bar(x1,y1,color = "cyan",width = 0.6)
plt.xlabel("month")
plt.ylabel("number")
plt.show()

# %%
data = sns.load_dataset("iris")
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
fig1 = plt.figure(figsize=(10,10))
plt.subplot2grid((3,2),(0,0))
plt.scatter(data.sepal_length,data.petal_length)
plt.xlabel("s_l")
plt.ylabel("p_l")
plt.title("s_l VS p_l")

fig2 = plt.figure(figsize=(10,10))
plt.subplot2grid((3,2),(0,0))
plt.scatter(data.sepal_length,data.petal_width)
plt.xlabel("s_l")
plt.ylabel("p_w")
plt.title("s_l VS p_w")

fig3 = plt.figure(figsize=(10,10))
plt.subplot2grid((3,2),(0,0))
plt.scatter(data.sepal_width,data.petal_length)
plt.xlabel("s_w")
plt.ylabel("p_l")
plt.title("s_w VS p_l")

fig4 = plt.figure(figsize=(10,10))
plt.subplot2grid((3,2),(0,0))
plt.scatter(data.sepal_width,data.petal_width)
plt.xlabel("s_w")
plt.ylabel("p_w")
plt.title("s_w VS p_w")
# Out:
# Text(0.5, 1.0, 's_w VS p_w')

# %%
# map_color = {'setosa':'green', 'versicolor':'red', 'virginica':'black'}
# colors = data['species'].map(map_color)
# plt.figure(figsize=(20,20))
# plt.subplot(2,2,1)
# plt.scatter(data['sepal_length'],data['petal_length'],c = colors)
# plt.title("s_l vs p_l")
# plt.xlabel("s_l")
# plt.ylabel("p_l")

# map_color = {'setosa':'green', 'versicolor':'red', 'virginica':'black'}
# colors = data['species'].map(map_color)
# plt.figure(figsize=(20,20))
# plt.subplot(2,2,1)
# plt.scatter(data['sepal_length'],data['petal_width'],c = colors)
# plt.title("s_l vs p_w")
# plt.xlabel("s_l")
# plt.ylabel("p_w")

# map_color = {'setosa':'green', 'versicolor':'red', 'virginica':'black'}
# colors = data['species'].map(map_color)
# plt.figure(figsize=(20,20))
# plt.subplot(2,2,1)
# plt.scatter(data['sepal_width'],data['petal_length'],c = colors)
# plt.title("s_w vs p_l")
# plt.xlabel("s_w")
# plt.ylabel("p_l")

# map_color = {'setosa':'green', 'versicolor':'red', 'virginica':'black'}
# colors = data['species'].map(map_color)
# plt.figure(figsize=(20,20))
# plt.subplot(2,2,1)
# plt.scatter(data['sepal_width'],data['petal_width'],c = colors)
# plt.title("s_w vs p_w")
# plt.xlabel("s_w")
# plt.ylabel("p_w")

# %%
set(data['species'])
# Out:
# {'setosa', 'versicolor', 'virginica'}

# %%
# set(data['species'])
flag = 1
plt.figure(figsize=(6,18))
for i in set(data['species']):
    plt.subplot(3,1,flag)
    flag = flag + 1
    data1 = data[data['species'] == i].drop('species',axis = 1)
    labels = data1.columns
    plt.title("the box with 4 features for the " +i+ " flowers")
    plt.xlabel("Features of the " +i+ " flowers")
    plt.boxplot(data1,vert=True
                , patch_artist=True
                ,labels=labels
                ,boxprops=dict(color='blue',facecolor='red')
                ,meanprops=dict(color="blue")
                ,capprops=dict(color="blue")
                ,whiskerprops=dict(color="red")
                ,medianprops=dict(color="blue"))

# %%
data = sns.load_dataset("tips")
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(10,10))
plt.scatter(data['total_bill'],data['tip'],color="b")

# %%
sexs = np.unique(data['sex'].values)
sex_money = []
for sex in sexs:
    sex_money.append(data[data['sex'] == sex]['tip'].values)
sex_money
# Out:
# [array([1.01, 3.61, 5.  , 3.02, 1.67, 3.5 , 2.75, 2.23, 3.  , 3.  , 2.45,
#         3.07, 2.6 , 5.2 , 1.5 , 2.47, 1.  , 3.  , 3.14, 5.  , 2.2 , 1.83,
#         5.17, 1.  , 4.3 , 3.25, 2.5 , 3.  , 2.5 , 3.48, 4.08, 4.  , 1.  ,
#         4.  , 3.5 , 1.5 , 1.8 , 2.92, 1.68, 2.52, 4.2 , 2.  , 2.  , 2.83,
#         1.5 , 2.  , 3.25, 1.25, 2.  , 2.  , 2.75, 3.5 , 5.  , 2.3 , 1.5 ,
#         1.36, 1.63, 5.14, 3.75, 2.61, 2.  , 3.  , 1.61, 2.  , 4.  , 3.5 ,
#         3.5 , 4.19, 5.  , 2.  , 2.01, 2.  , 2.5 , 3.23, 2.23, 2.5 , 6.5 ,
#         1.1 , 3.09, 3.48, 3.  , 2.5 , 2.  , 2.88, 4.67, 2.  , 3.  ]),
#  array([ 1.66,  3.5 ,  3.31,  4.71,  2.  ,  3.12,  1.96,  3.23,  1.71,
#          1.57,  3.  ,  3.92,  3.71,  3.35,  4.08,  7.58,  3.18,  2.34,
#          2.  ,  2.  ,  4.3 ,  1.45,  2.5 ,  3.27,  3.6 ,  2.  ,  2.31,
#          5.  ,  2.24,  2.54,  3.06,  1.32,  5.6 ,  3.  ,  5.  ,  6.  ,
#          2.05,  3.  ,  2.5 ,  1.56,  4.34,  3.51,  3.  ,  1.76,  6.73,
# ...

# %%
# plt.figure(figsize=(2,18))
fig,ax = plt.subplots()
# ax.set_xticklabels(sexs)
labels = ['Female','Male']
plt.title("The box with 2 features for the tip")
plt.xlabel("Features of the sex")
plt.ylabel("Values of tip")
ax.boxplot(sex_money,vert=True
                , patch_artist=True
                ,labels=labels
                ,boxprops=dict(color='blue',facecolor='red')
                ,meanprops=dict(color="blue")
                ,capprops=dict(color="blue")
                ,whiskerprops=dict(color="red")
                ,medianprops=dict(color="blue"))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b3a1f8dc10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b3a1fa3190>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x1b3a1f8d850>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1b3a1fa36d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1b3a1fa3970>,
# ...
#  'means': []}

# %%
smokers = np.unique(data['smoker'].values)
smoker_tip = []
for smoker in smokers:
    smoker_tip.append(data[data['smoker']==smoker]['tip'].values)
smoker_tip
# Out:
# [array([1.01, 1.66, 3.5 , 3.31, 3.61, 4.71, 2.  , 3.12, 1.96, 3.23, 1.71,
#         5.  , 1.57, 3.  , 3.02, 3.92, 1.67, 3.71, 3.5 , 3.35, 4.08, 2.75,
#         2.23, 7.58, 3.18, 2.34, 2.  , 2.  , 4.3 , 3.  , 1.45, 2.5 , 3.  ,
#         2.45, 3.27, 3.6 , 2.  , 3.07, 2.31, 5.  , 2.24, 2.54, 3.06, 1.32,
#         5.6 , 3.  , 5.  , 6.  , 2.05, 3.  , 2.5 , 2.6 , 5.2 , 1.56, 4.34,
#         3.51, 1.5 , 6.73, 2.64, 3.15, 2.47, 2.01, 1.97, 3.  , 2.2 , 1.25,
#         4.  , 3.  , 2.71, 3.4 , 1.83, 2.03, 5.17, 2.  , 4.  , 5.85, 3.  ,
#         3.5 , 3.25, 1.5 , 4.08, 3.76, 3.  , 1.  , 4.  , 2.55, 4.  , 3.5 ,
#         5.07, 1.5 , 1.8 , 2.92, 2.31, 1.68, 2.5 , 2.  , 2.52, 4.2 , 1.48,
#         2.  , 2.  , 2.18, 1.5 , 2.83, 1.5 , 2.  , 3.25, 1.25, 2.  , 2.  ,
#         2.75, 3.5 , 6.7 , 5.  , 5.  , 2.3 , 1.5 , 1.36, 1.63, 1.73, 2.  ,
#         2.5 , 2.  , 2.74, 2.  , 2.  , 5.14, 5.  , 3.75, 2.61, 2.  , 3.5 ,
#         2.5 , 2.  , 2.  , 3.48, 2.24, 4.5 , 5.  , 1.44, 9.  , 3.  , 3.  ,
# ...

# %%
# plt.figure(figsize=(2,18))
fig,ax = plt.subplots()
# ax.set_xticklabels(sexs)
labels = ['No','Yes']
plt.title("The box with 2 features for the tip")
plt.xlabel("Features of the smoker")
plt.ylabel("Values of tip")
ax.boxplot(smoker_tip,vert=True
                , patch_artist=True
                ,labels=labels
                ,boxprops=dict(color='blue',facecolor='red')
                ,meanprops=dict(color="blue")
                ,capprops=dict(color="blue")
                ,whiskerprops=dict(color="red")
                ,medianprops=dict(color="blue"))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b3a2013b20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b3a20230a0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x1b3a2013700>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1b3a20235e0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1b3a2023880>,
# ...
#  'means': []}

# %%
data.groupby(data['day']).size()
# Out:
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# dtype: int64

# %%
Sun_tip=data[data['day']=='Sun']['tip']
Sat_tip=data[data['day']=='Sat']['tip']
Thur_tip=data[data['day']=='Thur']['tip']
Fri_tip=data[data['day']=='Fri']['tip']
labels=['Sun','Sat','Thur','Fri']
plt.title("the box wirh 4 features for the tip")
plt.xlabel("Features of the day")
plt.ylabel("Valuse of tipFri_tip")
plt.boxplot([Sun_tip,Sat_tip,Thur_tip,Fri_tip],vert=True, patch_artist=True,labels=labels,boxprops=dict(color='blue',facecolor='red'),meanprops=dict(color="blue"),capprops=dict(color="blue"),whiskerprops=dict(color="red"),medianprops=dict(color="blue"))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b3a206d0a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b3a206d4c0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x1b3a21dbcd0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1b3a206da00>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1b3a206dca0>,
# ...
#  'means': []}

# %%
times = np.unique(data['time'].values)
times
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
# array(['Dinner','Lunch'],dtype=object)
time_tip = []
for time in times:
    time_tip.append(data[data['time']==time].values)
time_tip
# Out:
# [array([[16.99, 1.01, 'Female', ..., 'Sun', 'Dinner', 2],
#         [10.34, 1.66, 'Male', ..., 'Sun', 'Dinner', 3],
#         [21.01, 3.5, 'Male', ..., 'Sun', 'Dinner', 3],
#         ...,
#         [22.67, 2.0, 'Male', ..., 'Sat', 'Dinner', 2],
#         [17.82, 1.75, 'Male', ..., 'Sat', 'Dinner', 2],
#         [18.78, 3.0, 'Female', ..., 'Thur', 'Dinner', 2]], dtype=object),
#  array([[27.2, 4.0, 'Male', 'No', 'Thur', 'Lunch', 4],
#         [22.76, 3.0, 'Male', 'No', 'Thur', 'Lunch', 2],
#         [17.29, 2.71, 'Male', 'No', 'Thur', 'Lunch', 2],
#         [19.44, 3.0, 'Male', 'Yes', 'Thur', 'Lunch', 2],
#         [16.66, 3.4, 'Male', 'No', 'Thur', 'Lunch', 2],
#         [10.07, 1.83, 'Female', 'No', 'Thur', 'Lunch', 1],
#         [32.68, 5.0, 'Male', 'Yes', 'Thur', 'Lunch', 2],
#         [15.98, 2.03, 'Male', 'No', 'Thur', 'Lunch', 2],
#         [34.83, 5.17, 'Female', 'No', 'Thur', 'Lunch', 4],
#         [13.03, 2.0, 'Male', 'No', 'Thur', 'Lunch', 2],
# ...

# %%
Dinner_tip=data[data['time']=='Dinner']['tip']
Lunch_tip=data[data['time']=='Lunch']['tip']
labels=['Dinner','Lunch']
plt.title("the box wirh 2 features for the tip")
plt.xlabel("Features of the Time")
plt.ylabel("Valuse of tip")
plt.boxplot([Dinner_tip,Lunch_tip],vert=True, patch_artist=True,labels=labels,boxprops=dict(color='blue',facecolor='red'),meanprops=dict(color="blue"),capprops=dict(color="blue"),whiskerprops=dict(color="red"),medianprops=dict(color="blue"))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b3a2117a30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b3a2117e50>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x1b3a21176a0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1b3a21283d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1b3a2128670>,
# ...
#  'means': []}

# %%
foreat = data.groupby(['smoker','sex'])['tip'].mean(numeric_only = True)
foreat
# Out:
# smoker  sex
# Yes     Male      3.051167
#         Female    2.931515
# No      Male      3.113402
#         Female    2.773519
# Name: tip, dtype: float64

# %%
import numpy as np
x = np.arange(0,4,2)
width=0.5
x1 = x-width/2
x2 = x+width/2
y1=foreat['Yes']
y2=foreat['No']
plt.bar(x1,y1,width=0.5,label='Yes',color='teal',edgecolor='k',zorder=2)
plt.bar(x2,y2,width=0.5,label='No',color='navy',edgecolor='k',zorder=2)
plt.legend(frameon=False)
plt.xticks(x,['Male','Female'],fontsize=10)
plt.tick_params(axis='x',length=0)
plt.tight_layout()

# %%
data2 = sns.load_dataset("titanic")
data2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
def stackedbarplot(gb, y_data_names, colors, x_label, y_label, title): 

    num_gb_surv_ornot = data2[['survived',gb]].groupby(gb).sum()      
    num_gb_surv_ornot['unservived'] = data2[gb].value_counts()       
    num_gb_surv_ornot['survived']
    num_gb_surv_ornot['total'] = data2[gb].value_counts()
    num_gb_surv_ornot['survived_prop'] = num_gb_surv_ornot['survived']/num_gb_surv_ornot['total']      
    num_gb_surv_ornot['unsurvived_prop'] = num_gb_surv_ornot['unservived']/num_gb_surv_ornot['total']
    print(num_gb_surv_ornot)
    x_data = [i+1 for i in range(len(data2[gb].unique()))]         
    y_data_list = [num_gb_surv_ornot['survived_prop'],
                   num_gb_surv_ornot['unsurvived_prop']]
    _, ax = plt.subplots()
    for i in range(0, len(y_data_list)):
        if i == 0:
            ax.bar(x_data, y_data_list[i], color = colors[i],
                   align ='center', label = y_data_names[i])
        else:
            ax.bar(x_data, y_data_list[i], color = colors[i],
                   bottom = y_data_list[i - 1], align = 'center',
                   label = y_data_names[i])
        ax.set_xticks(np.linspace(1,len(num_gb_surv_ornot),          
                                  len(num_gb_surv_ornot)))
        ax.set_xticklabels(num_gb_surv_ornot.index)
        ax.set_ylabel(y_label)
        ax.set_xlabel(x_label)
        ax.set_title(title)
        ax.legend(loc = (1,1))

# %%
stackedbarplot(gb = 'pclass'
               , y_data_names = ['Survived', 'Unservived']
               , colors = ['#539caf', '#7663b0']
               , x_label = 'Pclass'
               , y_label = 'Proportion of survived/unsurvived'
               , title = 'Proportion of survived/unsurvived by Pclass (1, 2, 3)')
# Out:
#         survived  unservived  total  survived_prop  unsurvived_prop
# pclass
# 1            136         216    216       0.629630              1.0
# 2             87         184    184       0.472826              1.0
# 3            119         491    491       0.242363              1.0

# %%
# # 绘制堆积柱状图
# def stackedbarplot(x_data, y_data_list, y_data_names, colors, x_label, y_label, title):
#     _, ax = plt.subplots()
#     # 循环绘制堆积柱状图
#     for i in range(0, len(y_data_list)):
#         if i == 0:
#             ax.bar(x_data, y_data_list[i], color = colors[i], align = 'center', label = y_data_names[i])
#         else:
#             ax.bar(x_data, y_data_list[i], color = colors[i], bottom = y_data_list[i - 1], align = 'center', label = y_data_names[i])
#     ax.set_ylabel(y_label)
#     ax.set_xlabel(x_label)
#     ax.set_title(title)
#     ax.legend(loc = 'upper right') 


# stackedbarplot(x_data = survived_pclass.index.values
#                , y_data_list = [survived_pclass['yes_prop'], survived_pclass['no_prop']]
#                , y_data_names = ['Survived', 'Not survived']
#                , colors = ['#539caf', '#7663b0']
#                , x_label = 'Pclass'
#                , y_label = 'Proportion of survived/unsurvived'
#                , title = 'Proportion of survived/unsurvived by Pclass(1,2,3)')

# %%
stackedbarplot(gb = 'sex'
               , y_data_names = ['Survived', 'Unservived']
               , colors = ['#539caf', '#7663b0']
               , x_label = 'Pclass'
               , y_label = 'Proportion of survived/unsurvived'
               , title = 'Proportion of survived/unsurvived by Pclass (1, 2, 3)')
# Out:
#         survived  unservived  total  survived_prop  unsurvived_prop
# sex
# female       233         314    314       0.742038              1.0
# male         109         577    577       0.188908              1.0

# %%
# def boxplot(x_data,y_data,base_color,median_color,x_label,y_label,title):
#     flg,ax = plt.subplots()
#     ax.boxplot(y_data
#                , patch_artist=True
#                , medianprops = {'color':base_color}
#                , boxprops={'color':base_color,'facecolor':median_color}
#                , whiskerprops={'color':median_color}
#                , capprops={'color':base_color})
    
#     ax.set_xticklabels(x_data)
#     ax.set_ylabel(y_label)
#     ax.set_xlabel(x_label)
#     ax.set_title(title)


# survived = data['survived'].unique()
# bp_data = [data[data['survived']==survived[0]]['fare'],data[data['survived']==survived[1]['fare']]]

# boxplot(x_data=survived
#         ,y_data=bp_data
#         ,base_color = 'b'
#         ,median_color='r'
#         ,x_label='survived'
#         ,y_label='fare'
#         ,title='')

# %%
Survivied=data2[data2['survived']==1]['fare']
Unsurvivied=data2[data2['survived']==0]['fare']
plt.title("the box with 2 features for the fare")
plt.xlabel("Features of the survived")
plt.ylabel("Valuse of fare")
labels=['0','1']
plt.boxplot([Unsurvivied,Survivied]
            ,vert=True
            , patch_artist=True
            ,labels=labels
            ,boxprops=dict(color='blue',facecolor='red')
            ,meanprops=dict(color="blue")
            ,capprops=dict(color="blue")
            ,whiskerprops=dict(color="red")
            ,medianprops=dict(color="blue"))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b3a66e5be0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b3a66f9160>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x1b3a639a160>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1b3a66f96a0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1b3a66f9940>,
# ...
#  'means': []}

# %%
def boxplot(x_data, y_data, y_value, base_color, median_color):
    x_feature = data2[x_data].unique()                                     #提取出某个特征的种类
    bp_data = []
    for item in x_feature:
        bp_data.append(y_data[y_data[x_data] == item] [y_value].values)       #提取出某种类的数据
    _, ax = plt.subplots()
    ax.boxplot(bp_data,
               patch_artist = True,
               medianprops = {'color': base_color},
               boxprops = {'color': base_color, 'facecolor': median_color},
               whiskerprops = {'color': median_color},
               capprops = {'color': base_color})
    ax.set_xticklabels(x_feature)
    ax.set_ylabel('Values of %s' % y_value)
    ax.set_xlabel('Features of the %s '
                  % x_data)
    ax.set_title('The box with %d features for the %s'
                 % (len(x_feature), y_value) )

# %%
boxplot(x_data = 'survived'
        , y_data = data2[['survived','age']].dropna()
        , y_value = 'age'
        , base_color = 'b'
        , median_color = 'r')

# %%
size_pclass = pd.pivot_table(data2,index='embarked',columns='pclass',aggfunc='size')  


def groupedbarplot(x_data, y_data_list, y_data_names, colors, x_label, y_label, title):
    print(size_pclass)
    flg, ax = plt.subplots()
    total_width = 0.8
    ind_width = total_width / len(y_data_list)
    alteration = np.arange(-total_width/2+ind_width/2,
                           total_width/2+ind_width/2, ind_width)
    x_data = [i for i in range(len(x_data))]                                      
    for i in range(0, len(y_data_list)):
        ax.bar(x_data + alteration[i], y_data_list[i], color = colors[i],
               label = y_data_names[i], width = ind_width)
    ax.set_ylabel(y_label)
    ax.set_xlabel(x_label)
    ax.set_title(title)
    ax.set_xticks(np.linspace(0,2,3))
    ax.set_xticklabels(size_pclass.columns)
    ax.legend(loc = 'upper left')

# %%
size_pclass
# Out:
# pclass      1    2    3
# embarked
# C          85   17   66
# Q           2    3   72
# S         127  164  353

# %%
total_width = 9
ind_width = total_width / 3
alteration = np.arange(-total_width/2+ind_width/2,
                           total_width/2+ind_width/2, ind_width)

groupedbarplot(x_data = size_pclass.index.values
               , y_data_list = [size_pclass[1],
                                size_pclass[2],
                                size_pclass[3]]
               , y_data_names = ['C', 'Q', 'S']
               , colors = ['#539caf', '#7663b0', '#910caf']
               , x_label = 'Embarked'
               , y_label = 'Number of pepole for different kind of pclass'
               , title = 'Number of pepole for different kind of pclass by Embarked')
# Out:
# pclass      1    2    3
# embarked
# C          85   17   66
# Q           2    3   72
# S         127  164  353

# %%
boxplot(x_data = 'survived'
        , y_data = data2
        , y_value = 'sibsp'
        , base_color = 'b'
        , median_color = 'r')
data2['sibsp'].value_counts()
# Out:
# sibsp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
size_by_alone_survived = pd.pivot_table(data2,index='alone',columns='survived',aggfunc='size')
def groupedbarplot(x_data, y_data_list, y_data_names, colors, x_label,
                   y_label, title):
    print(size_by_alone_survived)
    _, ax = plt.subplots()
    total_width = 0.8
    ind_width = total_width / len(y_data_list)
    alteration = np.arange(-total_width/2+ind_width/2,
                           total_width/2+ind_width/2, ind_width)
    x_data = [i for i in range(len(x_data))]
    for i in range(0, len(y_data_list)):
        ax.bar(x_data + alteration[i], y_data_list[i], color = colors[i],
               label = y_data_names[i], width = ind_width)
    ax.set_ylabel(y_label)
    ax.set_xlabel(x_label)
    ax.set_title(title)
    ax.set_xticks(np.linspace(0,1,2))
    ax.set_xticklabels(size_by_alone_survived.index)
    ax.legend(loc = 'upper left')

# %%
groupedbarplot(x_data = size_by_alone_survived.index.values
               , y_data_list = [size_by_alone_survived[0],
                                size_by_alone_survived[1]]
               , y_data_names = ['0', '1']
               , colors = ['#539caf', '#7663b0']
               , x_label = 'alone'
               , y_label = 'The number of pepole'
               , title = 'The number of pepole by whether be survived or alone or not ')
# Out:
# survived    0    1
# alone
# False     175  179
# True      374  163
