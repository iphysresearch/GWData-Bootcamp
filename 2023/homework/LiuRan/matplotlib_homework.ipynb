# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = sns.load_dataset("flights")
data.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
x=data.groupby('year').sum(numeric_only=True)

# %%
x=x.reset_index()

# %%
plt.plot(x['year'],x['passengers'])
plt.title("the numble of passengers in each year")
plt.xlabel("year")
plt.ylabel("number")
# Out:
# Text(0, 0.5, 'number')

# %%
x1=data.groupby('month').sum(numeric_only=True)
x1=x1.reset_index()
plt.figure(figsize=(8,6))
plt.bar(x1['month'].index.values+1,x1['passengers'])
plt.title("the numble of passengers in each month")
plt.xlabel("month")
plt.ylabel("number")
# Out:
# Text(0, 0.5, 'number')

# %%
data1 = sns.load_dataset("iris")
data1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
color_map={'setosa':'green', 'versicolor':'red', 'virginica':'black'}
colors=data1['species'].map(color_map)
plt.figure(figsize=(20,20))
plt.subplot(2,2,1)
plt.scatter(data1['sepal_length'],data1['petal_length'],c=colors)
plt.title("s_l VS. p_l")
plt.xlabel("s_l")
plt.ylabel("p_l")
# plt.subplot(2,2,2)
# plt.scatter(data1['sepal_length'],data1['petal_width'])
# plt.title("s_l VS. p_w")
# plt.xlabel("s_l")
# plt.ylabel("p_w")
# plt.subplot(2,2,3)
# plt.scatter(data1['sepal_width'],data1['petal_length'])
# plt.title("s_w VS. p_l")
# plt.xlabel("s_w")
# plt.ylabel("p_l")
# plt.subplot(2,2,4)
# plt.scatter(data1['sepal_width'],data1['petal_width'])
# plt.title("s_w VS. p_w")
# plt.xlabel("s_w")
# plt.ylabel("p_w")
# plt.subplots_adjust(wspace=0.4, hspace=0.4)
# Out:
# Text(0, 0.5, 'p_l')

# %%
sepal=data1.columns[:2]
petal=data1.columns[2:4]
petal[0][0]+petal[0][6]
nums=1
plt.figure(figsize=(20,20))
for i in sepal:
    for j in petal:
        plt.subplot(2,2,nums)
        nums=nums+1
        plt.scatter(data1[i],data1[j])
        plt.title(i[0]+"_"+i[6]+" VS ."+j[0]+"_"+j[6])
        plt.xlabel(i[0]+"_"+i[6])
        plt.ylabel(j[0]+"_"+j[6])

# %%
color_map={'setosa':'c', 'versicolor':'red', 'virginica':'black'}
colors=data1['species'].map(color_map)
sepal=data1.columns[:2]
petal=data1.columns[2:4]
petal[0][0]+petal[0][6]
nums=1
plt.figure(figsize=(20,20))
for i in sepal:
    for j in petal:
        plt.subplot(2,2,nums)
        nums=nums+1
        plt.scatter(data1[i],data1[j],c=colors)
        plt.title(i[0]+"_"+i[6]+" VS ."+j[0]+"_"+j[6])
        plt.xlabel(i[0]+"_"+i[6])
        plt.ylabel(j[0]+"_"+j[6])

# %%
# plt.figure(figsize=(7,21))
# plt.subplot(3,1,1)
# setosa_data=data1[data1['species']=='setosa'].drop('species',axis=1)
# labels=setosa_data.columns
# plt.title("the box wirh 4 features for the setosa flowers")
# plt.xlabel("Features of the setosa flowers")
# plt.boxplot(setosa_data,vert=True, patch_artist=True,labels=labels,boxprops=dict(color='blue',facecolor='red'),meanprops=dict(color="blue"),capprops=dict(color="blue"),whiskerprops=dict(color="red"),medianprops=dict(color="blue"))
# plt.subplot(3,1,2)
# versicolor_data=data1[data1['species']=='versicolor'].drop('species',axis=1)
# labels=versicolor_data.columns
# plt.title("the box wirh 4 features for the versicolor flowers")
# plt.xlabel("Features of the versicolor flowers")
# plt.boxplot(versicolor_data,vert=True, patch_artist=True,labels=labels,boxprops=dict(color='blue',facecolor='red'),meanprops=dict(color="blue"),capprops=dict(color="blue"),whiskerprops=dict(color="red"),medianprops=dict(color="blue"))
# plt.subplot(3,1,3)
# virginica_data=data1[data1['species']=='virginica'].drop('species',axis=1)
# labels=virginica_data.columns
# plt.title("the box wirh 4 features for the virginica flowers")
# plt.xlabel("Features of the virginica flowers")
# plt.boxplot(virginica_data,vert=True, patch_artist=True,labels=labels,boxprops=dict(color='blue',facecolor='red'),meanprops=dict(color="blue"),capprops=dict(color="blue"),whiskerprops=dict(color="red"),medianprops=dict(color="blue"))

# %%
set(data1['species'])
# Out:
# {'setosa', 'versicolor', 'virginica'}

# %%
nums=1
plt.figure(figsize=(6,18))
for i in  set(data1['species']):
    plt.subplot(3,1,nums)
    nums=nums+1
    data=data1[data1['species']==i].drop('species',axis=1)
    labels=data.columns
    plt.title("the box wirh 4 features for the " +i+" flowers")
    plt.xlabel("Features of the "+i+" flowers")
    plt.boxplot(data,vert=True, patch_artist=True,labels=labels,boxprops=dict(color='blue',facecolor='red'),meanprops=dict(color="blue"),capprops=dict(color="blue"),whiskerprops=dict(color="red"),medianprops=dict(color="blue"))

# %%
data2 = sns.load_dataset("tips")
data2
# 总消费，小费，性别，吸烟与否，就餐星期，就餐时间，就餐人数
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.scatter(data2['total_bill'],data2['tip'],s=10,c='teal')
plt.title("total bill vs. tip")
plt.xlabel("total bill")
plt.ylabel("tip")
# Out:
# Text(0, 0.5, 'tip')

# %%
Female_tip=data2[data2['sex']=='Female']['tip']
Male_tip=data2[data2['sex']=='Male']['tip']
labels=['Female','Male']
plt.title("the box wirh 2 features for the tip")
plt.xlabel("Features of the sex")
plt.ylabel("Valuse of tip")
plt.boxplot([Female_tip,Male_tip],vert=True, patch_artist=True,labels=labels,boxprops=dict(color='blue',facecolor='red'),meanprops=dict(color="blue"),capprops=dict(color="blue"),whiskerprops=dict(color="red"),medianprops=dict(color="blue"))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2291096a5e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2291096ab80>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x2291096a220>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x22910978190>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x22910978460>,
# ...
#  'means': []}

# %%
No_tip=data2[data2['smoker']=='No']['tip']
Yes_tip=data2[data2['smoker']=='Yes']['tip']
labels=['No','Yes']
plt.title("the box wirh 2 features for the tip")
plt.xlabel("Features of the smoker")
plt.ylabel("Valuse of tip")
plt.boxplot([No_tip,Yes_tip],vert=True, patch_artist=True,labels=labels,boxprops=dict(color='blue',facecolor='red'),meanprops=dict(color="blue"),capprops=dict(color="blue"),whiskerprops=dict(color="red"),medianprops=dict(color="blue"))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x229108c6a60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x229108c6730>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x22910d862b0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x229108c64c0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x229108a7e20>,
# ...
#  'means': []}

# %%
Sun_tip=data2[data2['day']=='Sun']['tip']
Sat_tip=data2[data2['day']=='Sat']['tip']
Thur_tip=data2[data2['day']=='Thur']['tip']
Fri_tip=data2[data2['day']=='Fri']['tip']
labels=['Sun','Sat','Thur','Fri']
plt.title("the box wirh 4 features for the tip")
plt.xlabel("Features of the day")
plt.ylabel("Valuse of tipFri_tip")
plt.boxplot([Sun_tip,Sat_tip,Thur_tip,Fri_tip],vert=True, patch_artist=True,labels=labels,boxprops=dict(color='blue',facecolor='red'),meanprops=dict(color="blue"),capprops=dict(color="blue"),whiskerprops=dict(color="red"),medianprops=dict(color="blue"))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x229105de730>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x229105deb20>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x229123d4730>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x229105de2b0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x229105ea6d0>,
# ...
#  'means': []}

# %%
Dinner_tip=data2[data2['time']=='Dinner']['tip']
Lunch_tip=data2[data2['time']=='Lunch']['tip']
labels=['Dinner','Lunch']
plt.title("the box wirh 2 features for the tip")
plt.xlabel("Features of the Time")
plt.ylabel("Valuse of tip")
plt.boxplot([Dinner_tip,Lunch_tip],vert=True, patch_artist=True,labels=labels,boxprops=dict(color='blue',facecolor='red'),meanprops=dict(color="blue"),capprops=dict(color="blue"),whiskerprops=dict(color="red"),medianprops=dict(color="blue"))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x229105f2e20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22910623370>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x229105f2eb0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x22910623e20>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x22910623eb0>,
# ...
#  'means': []}

# %%
# t_tip=data2[data2['size']=='2']['tip']
# t_tip=data2[data2['size']=='3']['tip']
# t_tip=data2[data2['size']=='4']['tip']
# t_tip=data2[data2['size']=='2']['tip']
# t_tip=data2[data2['size']=='2']['tip']
# t_tip=data2[data2['size']=='2']['tip']
# t_tip=data2[data2['size']=='2']['tip']
size_tip=[]
for i in  set(data2['size']):
    t_tip=data2[data2['size']==i]['tip']
    size_tip.append(t_tip)
plt.boxplot(size_tip,vert=True, patch_artist=True,boxprops=dict(color='blue',facecolor='red'),meanprops=dict(color="blue"),capprops=dict(color="blue"),whiskerprops=dict(color="red"),medianprops=dict(color="blue"))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x229104a5130>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x229104a5e80>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x22910168c10>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x229104a56a0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x229104a92e0>,
# ...
#  'means': []}

# %%
ss=data2.groupby(['smoker','sex'])['tip'].mean(numeric_only=True)
ss
# Out:
# smoker  sex
# Yes     Male      3.051167
#         Female    2.931515
# No      Male      3.113402
#         Female    2.773519
# Name: tip, dtype: float64

# %%
import numpy as np
x = np.arange(0,4,2)
width=0.5
x1 = x-width/2
x2 = x+width/2
y1=ss['Yes']
y2=ss['No']
plt.bar(x1,y1,width=0.5,label='Yes',color='teal',edgecolor='k',zorder=2)
plt.bar(x2,y2,width=0.5,label='No',color='navy',edgecolor='k',zorder=2)
plt.legend(frameon=False)
plt.xticks(x,['Male','Female'],fontsize=10)
plt.tick_params(axis='x',length=0)
plt.tight_layout()

# %%
data3 = sns.load_dataset("titanic")
data3
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import pandas as pd

# %%
data3['pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
#https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html#matplotlib.pyplot.bar
def stackedbarplot(gb, y_data_names, colors, x_label, y_label, title): 

    num_gb_surv_ornot = data3[['survived',gb]].groupby(gb).sum()      #统计一共有多少生存者
    num_gb_surv_ornot['unservived'] = data3[gb].value_counts()       #统计多少行
    num_gb_surv_ornot['survived']
    num_gb_surv_ornot['total'] = data3[gb].value_counts()
    num_gb_surv_ornot['survived_prop'] = num_gb_surv_ornot['survived']/num_gb_surv_ornot['total']      
    num_gb_surv_ornot['unsurvived_prop'] = num_gb_surv_ornot['unservived']/num_gb_surv_ornot['total']
    print(num_gb_surv_ornot)
    x_data = [i+1 for i in range(len(data3[gb].unique()))]         #设置bar的坐标
    y_data_list = [num_gb_surv_ornot['survived_prop'],
                   num_gb_surv_ornot['unsurvived_prop']]
    _, ax = plt.subplots()
    for i in range(0, len(y_data_list)):
        if i == 0:
            ax.bar(x_data, y_data_list[i], color = colors[i],
                   align ='center', label = y_data_names[i])
        else:
            ax.bar(x_data, y_data_list[i], color = colors[i],
                   bottom = y_data_list[i - 1], align = 'center',
                   label = y_data_names[i])
        ax.set_xticks(np.linspace(1,len(num_gb_surv_ornot),            #np.linspace(起始，终止，份数) 设置刻度
                                  len(num_gb_surv_ornot)))
        ax.set_xticklabels(num_gb_surv_ornot.index)
        ax.set_ylabel(y_label)
        ax.set_xlabel(x_label)
        ax.set_title(title)
        ax.legend(loc = (1,1))

# %%
stackedbarplot(gb = 'pclass'
               , y_data_names = ['Survived', 'Unservived']
               , colors = ['#539caf', '#7663b0']
               , x_label = 'Pclass'
               , y_label = 'Proportion of survived/unsurvived'
               , title = 'Proportion of survived/unsurvived by Pclass (1, 2, 3)')
# Out:
#         survived  unservived  total  survived_prop  unsurvived_prop
# pclass
# 1            136         216    216       0.629630              1.0
# 2             87         184    184       0.472826              1.0
# 3            119         491    491       0.242363              1.0

# %%
stackedbarplot(gb = 'sex'
               , y_data_names = ['Survived', 'Unservived']
               , colors = ['#539caf', '#7663b0']
               , x_label = 'Pclass'
               , y_label = 'Proportion of survived/unsurvived'
               , title = 'Proportion of survived/unsurvived by Pclass (1, 2, 3)')
# Out:
#         survived  unservived  total  survived_prop  unsurvived_prop
# sex
# female       233         314    314       0.742038              1.0
# male         109         577    577       0.188908              1.0

# %%
Survivied=data3[data3['survived']==1]['fare']
Unsurvivied=data3[data3['survived']==0]['fare']
plt.title("the box wirh 2 features for the fare")
plt.xlabel("Features of the survived")
plt.ylabel("Valuse of fare")
labels=['0','1']
plt.boxplot([Unsurvivied,Survivied],vert=True, patch_artist=True,labels=labels,boxprops=dict(color='blue',facecolor='red'),meanprops=dict(color="blue"),capprops=dict(color="blue"),whiskerprops=dict(color="red"),medianprops=dict(color="blue")),
# Out:
# ({'whiskers': [<matplotlib.lines.Line2D at 0x22914b849d0>,
# ...
#   'caps': [<matplotlib.lines.Line2D at 0x22914b84f70>,
# ...
#   'boxes': [<matplotlib.patches.PathPatch at 0x22914b84610>,
# ...
#   'medians': [<matplotlib.lines.Line2D at 0x22914b95550>,
# ...
#   'fliers': [<matplotlib.lines.Line2D at 0x22914b95820>,
# ...
#   'means': []},)

# %%
#方法二
def boxplot(x_data, y_data, y_value, base_color, median_color):
    x_feature = data3[x_data].unique()                                     #提取出某个特征的种类
    bp_data = []
    for item in x_feature:
        bp_data.append(y_data[y_data[x_data] == item] [y_value].values)       #提取出某种类的数据
    _, ax = plt.subplots()
    ax.boxplot(bp_data,
               patch_artist = True,
               medianprops = {'color': base_color},
               boxprops = {'color': base_color, 'facecolor': median_color},
               whiskerprops = {'color': median_color},
               capprops = {'color': base_color})
    ax.set_xticklabels(x_feature)
    ax.set_ylabel('Values of %s' % y_value)
    ax.set_xlabel('Features of the %s '
                  % x_data)
    ax.set_title('The box with %d features for the %s'
                 % (len(x_feature), y_value) )

# %%
boxplot(x_data = 'survived'
        , y_data = data3[['survived','fare']].dropna()
        , y_value = 'fare'
        , base_color = 'b'
        , median_color = 'r')

# %%
boxplot(x_data = 'survived'
        , y_data = data3[['survived','age']].dropna()
        , y_value = 'age'
        , base_color = 'b'
        , median_color = 'r')

# %%
size_by_embarked_pclass = pd.pivot_table(data3,index='embarked',columns='pclass',aggfunc='size')   #以embarked分类，以pclass的种类为列，统计pclass对应于embarked的个数
def groupedbarplot(x_data, y_data_list, y_data_names, colors, x_label, y_label, title):
    print(size_by_embarked_pclass)
    _, ax = plt.subplots()
    total_width = 0.8
    ind_width = total_width / len(y_data_list)
    alteration = np.arange(-total_width/2+ind_width/2,
                           total_width/2+ind_width/2, ind_width)
    x_data = [i for i in range(len(x_data))]                                         #设置bars位置    
    for i in range(0, len(y_data_list)):
        ax.bar(x_data + alteration[i], y_data_list[i], color = colors[i],
               label = y_data_names[i], width = ind_width)
    ax.set_ylabel(y_label)
    ax.set_xlabel(x_label)
    ax.set_title(title)
    ax.set_xticks(np.linspace(0,2,3))
    ax.set_xticklabels(size_by_embarked_pclass.columns)
    ax.legend(loc = 'upper left')

# %%
size_by_embarked_pclass
# Out:
# pclass      1    2    3
# embarked
# C          85   17   66
# Q           2    3   72
# S         127  164  353

# %%
total_width = 9
ind_width = total_width / 3
alteration = np.arange(-total_width/2+ind_width/2,
                           total_width/2+ind_width/2, ind_width)
alteration
# Out:
# array([-3.,  0.,  3.])

# %%
groupedbarplot(x_data = size_by_embarked_pclass.index.values
               , y_data_list = [size_by_embarked_pclass[1],
                                size_by_embarked_pclass[2],
                                size_by_embarked_pclass[3]]
               , y_data_names = ['C', 'Q', 'S']
               , colors = ['#539caf', '#7663b0', '#910caf']
               , x_label = 'Embarked'
               , y_label = 'Number of pepole for different kind of pclass'
               , title = 'Number of pepole for different kind of pclass by Embarked')
# Out:
# pclass      1    2    3
# embarked
# C          85   17   66
# Q           2    3   72
# S         127  164  353

# %%
boxplot(x_data = 'survived'
        , y_data = data3
        , y_value = 'sibsp'
        , base_color = 'b'
        , median_color = 'r')
data3['sibsp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: sibsp, dtype: int64

# %%
boxplot(x_data = 'survived'
        , y_data = data3
        , y_value = 'parch'
        , base_color = 'b'
        , median_color = 'r')
data3['parch'].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: parch, dtype: int64

# %%
size_by_alone_survived = pd.pivot_table(data3,index='alone',columns='survived',aggfunc='size')
def groupedbarplot(x_data, y_data_list, y_data_names, colors, x_label,
                   y_label, title):
    print(size_by_alone_survived)
    _, ax = plt.subplots()
    total_width = 0.8
    ind_width = total_width / len(y_data_list)
    alteration = np.arange(-total_width/2+ind_width/2,
                           total_width/2+ind_width/2, ind_width)
    x_data = [i for i in range(len(x_data))]
    for i in range(0, len(y_data_list)):
        ax.bar(x_data + alteration[i], y_data_list[i], color = colors[i],
               label = y_data_names[i], width = ind_width)
    ax.set_ylabel(y_label)
    ax.set_xlabel(x_label)
    ax.set_title(title)
    ax.set_xticks(np.linspace(0,1,2))
    ax.set_xticklabels(size_by_alone_survived.index)
    ax.legend(loc = 'upper left')

# %%
groupedbarplot(x_data = size_by_alone_survived.index.values
               , y_data_list = [size_by_alone_survived[0],
                                size_by_alone_survived[1]]
               , y_data_names = ['0', '1']
               , colors = ['#539caf', '#7663b0']
               , x_label = 'alone'
               , y_label = 'The number of pepole'
               , title = 'The number of pepole by whether be survived or alone or not ')
# Out:
# survived    0    1
# alone
# False     175  179
# True      374  163
